# %%
import os
import requests
import json
import pandas as pd
import numpy as np
from config import NPS_key
import pprint as pp

# %%
quakes_url = "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/significant_week.geojson"

response = requests.get(quakes_url)     
data = response.json()

quake_data = data['features']
pp.pprint(data)
# Out:
# {'bbox': [-177.8343, -37.605, 8.99, 179.5975, 39.7886, 53.09],
#  'features': [{'geometry': {'coordinates': [179.5975, -37.605, 8.99],
#                             'type': 'Point'},
#                'id': 'us7000dg8x',
#                'properties': {'alert': 'green',
#                               'cdi': 5.8,
#                               'code': '7000dg8x',
#                               'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000dg8x.geojson',
#                               'dmin': 1.026,
#                               'felt': 16,
#                               'gap': 34,
#                               'ids': ',us7000dg8x,',
#                               'mag': 6.3,
#                               'magType': 'mww',
#                               'mmi': 4.968,
#                               'net': 'us',
#                               'nst': None,
#                               'place': '181 km NE of Gisborne, New Zealand',
# ...
